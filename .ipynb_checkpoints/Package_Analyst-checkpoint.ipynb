# %%
#Import Library yang dibutuhkan
from datetime import datetime
import pandas as pd
import numpy as np
from pandas.plotting import scatter_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler

# %%
#Baca Dataset Excel
df=pd.read_excel("dataset.xlsx")
df.head()
# Out:
#    Pengirim  Layanan  Sumber   Biaya  Status
# 0        17        1       7  374962       8
# 1        62        1       7  211860       8
# 2        31        1       7  174982       5
# 3        15        2       6  110000       8
# 4       123        2       6  105000       5

# %%
#Melihat Tipe Data Setiap Atribut
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2926 entries, 0 to 2925
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pengirim  2926 non-null   int64
#  1   Layanan   2926 non-null   int64
#  2   Sumber    2926 non-null   int64
#  3   Biaya     2926 non-null   int64
#  4   Status    2926 non-null   int64
# dtypes: int64(5)
# memory usage: 114.4 KB

# %%
#Mengetahui dimensi DataFrame 'df', yaitu jumlah baris dan kolom. 
df.shape
# Out:
# (2926, 5)

# %%
#Mengecek Apakah Ada Atribut yang Kodong Datanya
df.isnull().sum()
# Out:
# Pengirim    0
# Layanan     0
# Sumber      0
# Biaya       0
# Status      0
# dtype: int64

# %%
#Baris ini menghapus baris-baris yang memiliki nilai yang hilang (NaN) dari DataFrame 'df'
df.dropna(inplace =True)

# %%
#Membuat grafik Plotting 10 Pengirim terbanyak
plt_pengirim=df.Pengirim.value_counts()[0:20]
plt_pengirim=pd.DataFrame(plt_pengirim) 
plt_pengirim.columns=['Jumlah'] 
sns.barplot(data=plt_pengirim,y=plt_pengirim.index,x=plt_pengirim['Jumlah'])
# Out:
# <Axes: xlabel='Jumlah', ylabel='Pengirim'>

# %%
#Menghapus nilai negatif
df.drop(df[df['Biaya'] < 0].index, inplace = True) 
df.drop(df[df['Status'] < 0].index, inplace = True) 
df[df['Biaya']<0].shape[0], df[df['Status']<0].shape[0]
# Out:
# (0, 0)

# %%
#Menampilkan lima baris pertama dari DataFrame 'df'
df.head()
# Out:
#    Pengirim  Layanan  Sumber   Biaya  Status
# 0        17        1       7  374962       8
# 1        62        1       7  211860       8
# 2        31        1       7  174982       5
# 3        15        2       6  110000       8
# 4       123        2       6  105000       5

# %%
df['Status']=df['Status']
lt = df.groupby(['Pengirim'])['Status'].max().reset_index()
lt.head(20)
# Out:
#     Pengirim  Status
# 0          1       8
# 1          2       9
# 2          3       9
# 3          4       9
# 4          5       9
# 5          6       9
# 6          7       9
# 7          8       9
# 8          9       9
# 9         10       9
# 10        11       9
# 11        12       9
# 12        13       9
# 13        14       8
# 14        15       9
# 15        16       8
# 16        17       9
# 17        18       9
# 18        19       9
# 19        20       9

# %%
df['Frequency']= df['Pengirim']
nt=df.groupby('Pengirim')['Frequency'].sum().reset_index()
nt.head(20)
# Out:
#     Pengirim  Frequency
# 0          1          6
# 1          2         30
# 2          3        156
# 3          4         20
# 4          5         50
# 5          6         78
# 6          7         56
# 7          8         72
# 8          9        198
# 9         10        180
# 10        11        506
# 11        12        228
# 12        13        624
# 13        14        126
# 14        15       1305
# 15        16         80
# 16        17        612
# 17        18        720
# 18        19        323
# 19        20        440

# %%
df['TotalAmount']= df['Pengirim']*df['Biaya'] 
tm=df.groupby('Pengirim')['TotalAmount'].sum().reset_index()
tm.head(20)
# Out:
#     Pengirim  TotalAmount
# 0          1        30795
# 1          2       694986
# 2          3      3073332
# 3          4       682112
# 4          5      1413100
# 5          6      2253900
# 6          7       503265
# 7          8      1245600
# 8          9      3119229
# 9         10      4191530
# 10        11     11716540
# 11        12      5189196
# 12        13      5895877
# 13        14      2180570
# 14        15     52042425
# 15        16      3733120
# 16        17     25421834
# 17        18     18754488
# 18        19      8705838
# 19        20      9634500

# %%
merge1= pd.merge(lt, nt, how='inner', on='Pengirim') 
new_df=pd.merge(merge1,tm,how='inner',on= 'Pengirim') 
new_df.head(20)
# Out:
#     Pengirim  Status  Frequency  TotalAmount
# 0          1       8          6        30795
# 1          2       9         30       694986
# 2          3       9        156      3073332
# 3          4       9         20       682112
# 4          5       9         50      1413100
# 5          6       9         78      2253900
# 6          7       9         56       503265
# 7          8       9         72      1245600
# 8          9       9        198      3119229
# 9         10       9        180      4191530
# 10        11       9        506     11716540
# 11        12       9        228      5189196
# 12        13       9        624      5895877
# 13        14       8        126      2180570
# 14        15       9       1305     52042425
# 15        16       8         80      3733120
# 16        17       9        612     25421834
# 17        18       9        720     18754488
# 18        19       9        323      8705838
# 19        20       9        440      9634500

# %%
numeric_columns = new_df.select_dtypes(include=[np.number])
epsilon = 1e-8 
data_log = np.log(numeric_columns + epsilon) 
scaler = StandardScaler() 
scaler.fit(data_log) 
data_normalized = scaler.transform(data_log)
scaled = data_normalized 
data_norm = pd.DataFrame(data=data_normalized, index=numeric_columns.index, columns=numeric_columns.columns) 
plt.figure(figsize=(18, 10)) 
plt.subplot(3, 1, 1); sns.distplot(data_norm['Pengirim']) 
plt.subplot(3, 1, 2); sns.distplot(data_norm['Status']) 
plt.subplot(3, 1, 3); sns.distplot(data_norm['TotalAmount']) 
plt.show()

# %%
inertia = []
max_clusters = min(len(scaled), 10) 
for i in np.arange(1, max_clusters + 1) :
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(scaled) 
    inertia.append(kmeans.inertia_)
plt.figure(figsize=(10,6)) 
plt.plot(inertia, marker="o")

# %%
kmeans=KMeans(n_clusters=3) 
kmeans.fit(scaled) 
new_df["Clusters"]=(kmeans.labels_+1) 
new_df.head(20)
# Out:
#     Pengirim  Status  Frequency  TotalAmount  Clusters
# 0          1       8          6        30795         2
# 1          2       9         30       694986         2
# 2          3       9        156      3073332         2
# 3          4       9         20       682112         2
# 4          5       9         50      1413100         2
# 5          6       9         78      2253900         2
# 6          7       9         56       503265         2
# 7          8       9         72      1245600         2
# 8          9       9        198      3119229         2
# 9         10       9        180      4191530         2
# 10        11       9        506     11716540         2
# 11        12       9        228      5189196         2
# 12        13       9        624      5895877         2
# 13        14       8        126      2180570         3
# 14        15       9       1305     52042425         1
# 15        16       8         80      3733120         3
# 16        17       9        612     25421834         1
# 17        18       9        720     18754488         1
# 18        19       9        323      8705838         2
# 19        20       9        440      9634500         2

# %%
cluster_average=new_df.groupby('Clusters')[['TotalAmount']].mean()
cluster_average
# Out:
#            TotalAmount
# Clusters
# 1         4.384146e+07
# 2         4.508091e+06
# 3         1.567098e+07

# %%
def func(row): 
    if row["Clusters"]==1:
        return 'Pengirim Terbanyak'
    elif row["Clusters"]==2:
        return 'Pengirim dengan Kemungkinan Beresiko'
    else:
        return 'Pengirim Normal'
new_df['group']=new_df.apply(func, axis=1) 
new_df.head(20)
# Out:
#     Pengirim  Status  Frequency  TotalAmount  Clusters  \
# 0          1       8          6        30795         2
# 1          2       9         30       694986         2
# 2          3       9        156      3073332         2
# 3          4       9         20       682112         2
# 4          5       9         50      1413100         2
# 5          6       9         78      2253900         2
# 6          7       9         56       503265         2
# 7          8       9         72      1245600         2
# 8          9       9        198      3119229         2
# 9         10       9        180      4191530         2
# 10        11       9        506     11716540         2
# 11        12       9        228      5189196         2
# 12        13       9        624      5895877         2
# 13        14       8        126      2180570         3
# 14        15       9       1305     52042425         1
# 15        16       8         80      3733120         3
# 16        17       9        612     25421834         1
# 17        18       9        720     18754488         1
# 18        19       9        323      8705838         2
# 19        20       9        440      9634500         2
#
#                                    group
# 0   Pengirim dengan Kemungkinan Beresiko
# 1   Pengirim dengan Kemungkinan Beresiko
# 2   Pengirim dengan Kemungkinan Beresiko
# 3   Pengirim dengan Kemungkinan Beresiko
# 4   Pengirim dengan Kemungkinan Beresiko
# 5   Pengirim dengan Kemungkinan Beresiko
# 6   Pengirim dengan Kemungkinan Beresiko
# 7   Pengirim dengan Kemungkinan Beresiko
# 8   Pengirim dengan Kemungkinan Beresiko
# 9   Pengirim dengan Kemungkinan Beresiko
# 10  Pengirim dengan Kemungkinan Beresiko
# 11  Pengirim dengan Kemungkinan Beresiko
# 12  Pengirim dengan Kemungkinan Beresiko
# 13                       Pengirim Normal
# 14                    Pengirim Terbanyak
# 15                       Pengirim Normal
# 16                    Pengirim Terbanyak
# 17                    Pengirim Terbanyak
# 18  Pengirim dengan Kemungkinan Beresiko
# 19  Pengirim dengan Kemungkinan Beresiko

# %%
result=new_df.group.value_counts()  
result.plot(kind="barh")
# Out:
# <Axes: ylabel='group'>

# %%
new_df.to_excel('Hasil Cluster Analisis Pengiriman Package.xlsx', index=False)
